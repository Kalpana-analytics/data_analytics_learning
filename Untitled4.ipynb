# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalpana-analytics/data_analytics_learning/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# While Loop

# %%
i = 1

while i <= 5:
    print(i)
    i = i + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
l = 50

while l <= 65:
  print(l)
  l = l + 3
# Out:
# 50
# 53
# 56
# 59
# 62
# 65

# %% [markdown]
# Square program

# %%
for i in range(9,89):
   print(i*i)
# Out:
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
# 400
# 441
# 484
# 529
# 576
# 625
# 676
# 729
# 784
# 841
# 900
# 961
# 1024
# 1089
# 1156
# 1225
# 1296
# 1369
# 1444
# 1521
# 1600
# 1681
# 1764
# 1849
# 1936
# 2025
# 2116
# 2209
# 2304
# 2401
# 2500
# 2601
# 2704
# 2809
# 2916
# 3025
# 3136
# 3249
# 3364
# 3481
# 3600
# 3721
# 3844
# 3969
# 4096
# 4225
# 4356
# 4489
# 4624
# 4761
# 4900
# 5041
# 5184
# 5329
# 5476
# 5625
# 5776
# 5929
# 6084
# 6241
# 6400
# 6561
# 6724
# 6889
# 7056
# 7225
# 7396
# 7569
# 7744

# %%
for i in range (67,90):
  print(i+i)
# Out:
# 134
# 136
# 138
# 140
# 142
# 144
# 146
# 148
# 150
# 152
# 154
# 156
# 158
# 160
# 162
# 164
# 166
# 168
# 170
# 172
# 174
# 176
# 178

# %% [markdown]
# If condition

# %%
k = 89

if k>76:
   print("hello world")
else:
   print("hi")
# Out:
# hello world

# %%
num = 10

if num > 0:
    print("Positive")
else:
    print("Negative")
# Out:
# Positive

# %% [markdown]
# Function (def)

# %%
def greet():
     print ("hello")
greet()
# Out:
# hello

# %%
def wishes():
    print("congrats")
wishes()
# Out:
# congrats

# %%
def add(a,b):
    print(a+b)

add(10,20)
# Out:
# 30

# %% [markdown]
# Upper case

# %%
name = "kalpu"

print(name.upper())
# Out:
# KALPU

# %% [markdown]
# Lower case

# %%
name = "KALPU"

print(name.lower())
# Out:
# kalpu

# %% [markdown]
# Tittle

# %%
name = "kalpana v"

print(name.title())
# Out:
# Kalpana V

# %% [markdown]
# Strings

# %%
name = "python"

print(name[0:3])
# Out:
# pyt

# %%
name = "python"

print(name[::-1])
# Out:
# nohtyp

# %%
name = "kalpana"

print(name[0])
print(name[-1]l\)
# Out:
# k
# a

# %% [markdown]
# step

# %%
for i in range(1,10,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for k in range(6,9,3):
  print(k)
# Out:
# 6

# %% [markdown]
# stop

# %%
for y in range(1,8):
  print(y)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
for s in range(78,89):
  print(s)
# Out:
# 78
# 79
# 80
# 81
# 82
# 83
# 84
# 85
# 86
# 87
# 88

# %% [markdown]
# Start

# %%
for k in range(123,567,789):
  print(k)
# Out:
# 123

# %%
for n in range(34,43,54):
  print(n)
# Out:
# 34
