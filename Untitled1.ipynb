# %% [markdown]
# Len

# %%
a=[8,0,7,6]
print(len(a))
# Out:
# 4

# %%
H=[78,90,89,78,67]
i=[88,88,78,67,67]
u=[66,89,45,67,34]
print(len(i))
print(len(u))
# Out:
# 5
# 5

# %%
j=[90,89,78]
l=[45,67]
print(len(l))
# Out:
# 2

# %% [markdown]
# Sort

# %%
o=[5,2,3,1,4,5,6,87]
k=[34,11,67,0,887]
k.sort()
o.sort()
print(k)
print(o)
# Out:
# [0, 11, 34, 67, 887]
# [1, 2, 3, 4, 5, 5, 6, 87]

# %%
j=[0,1,4,-5,-0,-2]
p=[-0,-7,-6.9,-1.2,-0.8]
j.sort()
p.sort()
print(j)
print(p)
# Out:
# [-5, -2, 0, 0, 1, 4]
# [-7, -6.9, -1.2, -0.8, 0]

# %% [markdown]
# Descending order

# %%
i=[90,234,6566,4584,-54646,-0.5568487,56556657,5466,223]
i.sort(reverse="false")
print(i)
i.sort(reverse="true")
print(i)
# Out:
# [56556657, 6566, 5466, 4584, 234, 223, 90, -0.5568487, -54646]
# [56556657, 6566, 5466, 4584, 234, 223, 90, -0.5568487, -54646]

# %%
u=[90,89,9090,899]
u.sort(reverse="true")
print(u)
# Out:
# [9090, 899, 90, 89]

# %% [markdown]
# sorted

# %%
y=[888,889,0.90,970,80]
q=[1,2,0,2,1,2,0]
z=sorted(y)
r=sorted(q)
print(z)
# Out:
# [0.9, 80, 888, 889, 970]

# %%
j=[90,80,100,0.9,1000,2]
u=sorted(j)
print(u)
# Out:
# [0.9, 2, 80, 90, 100, 1000]

# %% [markdown]
# Append

# %%
y=[90,56,78,45,91]
y.append(6)
print(y)
# Out:
# [90, 56, 78, 45, 91, 6]

# %%
i=[90,89,56,94,78]
i.append(0)
print(i)
# Out:
# [90, 89, 56, 94, 78, 0]

# %% [markdown]
# Insert

# %%
i=[90,89,78,67]
i.insert(2,56)
print(i)
# Out:
# [90, 89, 56, 78, 67]

# %%
k=[90,98,56,435,234]
t=[43,143,1343,14]
t.insert(1,45)
k.insert(4,23)
print(t)
print(k)
# Out:
# [43, 45, 143, 1343, 14]
# [90, 98, 56, 435, 23, 234]

# %% [markdown]
# Remove

# %%
kalpana=[19,20,21]
siri=[5,9,0]
siri.remove(0)
print(siri)
# Out:
# [5, 9]

# %%
Rohit=[45,33]
hardik=[33,45]
Rohit.remove(33)
hardik.remove(45)
print(Rohit)
print(hardik)
# Out:
# [45]
# [33]

# %% [markdown]
# Pop

# %%
r=[1,2,3]
k=[5,6,7]
k.pop(2)
print(k)
# Out:
# [5, 6]

# %%
i=[90,90,89,89,89]
o=[9,0,8,7,9]
i.pop(4)
print(i)
# Out:
# [90, 90, 89, 89]

# %% [markdown]
# Concatenation

# %%
virat=[18]
rohit=[45]
dhoni=[7]
jadeja=virat+rohit+dhoni
print(jadeja)
# Out:
# [18, 45, 7]

# %% [markdown]
# Reverse

# %%
e=[90,89,78,67,56,45,34,23,12]
d=[12,34,45,56,78,89,90]
e.reverse()
print(e)
# Out:
# [12, 23, 34, 45, 56, 67, 78, 89, 90]

# %%
g=[89,78,90,6776,7866,5544]
t=[0.9,9.0,98,908,675]
t.reverse()
print(t)
# Out:
# [675, 908, 98, 9.0, 0.9]
